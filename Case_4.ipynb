# %%
import openmc
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Materials Definition
       
       #FUEL
uo2_fuel = openmc.Material(name='UO2')                # enriched U of 2.35 wt.%
uo2_fuel.add_nuclide("U234", 0.000137, 'wo')
uo2_fuel.add_nuclide("U235", 0.02350, 'wo')
uo2_fuel.add_nuclide("U236", 0.000171, 'wo')
uo2_fuel.add_nuclide("U238", 0.976192, 'wo')
uo2_fuel.add_element("O", 0.12, 'wo')    #Oxygen mass_fraction (825g - 726g) 99g / 825g
uo2_fuel.set_density('g/cc', 9.20)


       #ALUMINUM 6061
Al_6061 = openmc.Material(name='6061 Aluminum')
Al_6061.add_element("Al", 0.97325, 'wo')
Al_6061.add_element("Cr", 0.002, 'wo')
Al_6061.add_element("Cu", 0.0025, 'wo')
Al_6061.add_element("Mg", 0.01, 'wo')
Al_6061.add_element("Ti", 0.00075, 'wo')
Al_6061.add_element("Zn", 0.00125, 'wo')
Al_6061.add_element("Si", 0.006, 'wo')
Al_6061.add_element("Fe", 0.0035, 'wo')
Al_6061.set_density('g/cc', 2.69)


       #ALUMINUM 1100
Al_1100 = openmc.Material(name='1100 Aluminum')
Al_1100.add_element("Al", 0.99, 'wo')
Al_1100.add_element("Cu", 0.0012, 'wo')
Al_1100.add_element("Mn", 0.00025, 'wo')
Al_1100.add_element("Zn", 0.0005, 'wo')
Al_1100.add_element("Si", 0.004025, 'wo')
Al_1100.add_element("Fe", 0.004025, 'wo')
Al_1100.set_density('g/cc', 2.7)

       #ALUMINUM 5052
Al_5052 = openmc.Material(name='5052 Aluminum')
Al_5052.add_element("Al", 0.9665, 'wo')
Al_5052.add_element("Cr", 0.0025, 'wo')
Al_5052.add_element("Cu", 0.0005, 'wo')
Al_5052.add_element("Mg", 0.025, 'wo')
Al_5052.add_element("Mn", 0.0005, 'wo')
Al_5052.add_element("Zn", 0.0005, 'wo')
Al_5052.add_element("Si", 0.00225, 'wo')
Al_5052.add_element("Fe", 0.00225, 'wo')
Al_5052.set_density('g/cc', 2.69)

       #Acrylic
acrylic = openmc.Material(name='Acrylic')
acrylic.add_element("H", 5.6642e-2, 'ao')
acrylic.add_element("C", 3.5648e-2, 'ao')
acrylic.add_element("O", 1.4273e-2, 'ao')
acrylic.set_density('g/cc', 1.185)

       #Water
water = openmc.Material(name='Water')
water.add_element("H", 6.6706e-2, 'ao')
water.add_element("O", 3.3353e-2, 'ao')
water.set_density('g/cc', 0.997766)

materials = openmc.Materials([uo2_fuel, Al_6061, Al_1100, Al_5052, acrylic, water])
materials.export_to_xml()

# %%
# Geometry Definitions

# %%
#Fuel Rod Geometry

fuel_bottom = openmc.ZPlane(z0=1.27) 
fuel_top = openmc.ZPlane(z0=92.71)            #fuel length
fuel = openmc.ZCylinder(r=1.1176/2, name='Fuel')

clad_bottom = openmc.ZPlane(z0=0) 
clad_top = openmc.ZPlane(z0=93.19)            #clad length
clad_or = openmc.ZCylinder(r=0.635, name='Clad Outer R')  #clad outer diameter

top_plug_1_bottom = openmc.ZPlane(z0=92.71)  
top_plug_1_top = openmc.ZPlane(z0=93.19)       #top end plug lower peace length
top_plug_1 = openmc.ZCylinder(r=1.1176/2, name='Top end plug lower peace')

top_plug_2_bottom = openmc.ZPlane(z0=93.19)  
top_plug_2_top = openmc.ZPlane(z0=98.27)       #top end plug upper peace length
top_plug_2 = openmc.ZCylinder(r=0.635, name='Top end plug upper peace')

lower_plug_bottom = openmc.ZPlane(z0=0)
lower_plug_top = openmc.ZPlane(z0=1.27)         #lower end plug length
lower_plug = openmc.ZCylinder(r=0.635, name='Lower end plug')

#Region Definitions

water_cell_x_min = openmc.XPlane(x0=-(2.032/2))
water_cell_x_max = openmc.XPlane(x0=+(2.032/2))
water_cell_y_min = openmc.YPlane(y0=-(2.032/2))
water_cell_y_max = openmc.YPlane(y0=+(2.032/2))
water_cell_top = openmc.ZPlane(z0=+98.27)
water_cell_bottom = openmc.ZPlane(z0=-2.54)

water_box_region = +water_cell_x_min & -water_cell_x_max & +water_cell_y_min & -water_cell_y_max & -water_cell_top & +water_cell_bottom

assembly_pitch = 2.032

acrylic_bottom = openmc.ZPlane(z0=-2.54)            #Acrylic plate thickness
acrylic_top = openmc.ZPlane(z0=0)
acrylic_x_min = openmc.XPlane(x0=-assembly_pitch/2)
acrylic_x_max = openmc.XPlane(x0=+assembly_pitch/2)
acrylic_y_min = openmc.YPlane(y0=-assembly_pitch/2)
acrylic_y_max = openmc.YPlane(y0=+assembly_pitch/2)  #Acrylic plate width and depth

acrylic_region = +acrylic_x_min & -acrylic_x_max & +acrylic_y_min & -acrylic_y_max & +acrylic_bottom & -acrylic_top
fuel_region = -fuel & -fuel_top & +fuel_bottom
clad_region = +fuel & -clad_or & -clad_top & +clad_bottom
top_plug_1_region = -top_plug_1 & -top_plug_1_top & +top_plug_1_bottom
top_plug_2_region = -top_plug_2 & -top_plug_2_top & +top_plug_2_bottom
lower_plug_region = -lower_plug & -lower_plug_top & +lower_plug_bottom
water_region = water_box_region & ~(fuel_region | clad_region | top_plug_1_region | top_plug_2_region | lower_plug_region | acrylic_region)

#Cell Definitions

fuel_cell = openmc.Cell(name="Fuel_UO2")
fuel_cell.fill = uo2_fuel
fuel_cell.region = fuel_region

clad_cell = openmc.Cell(name="Clad")
clad_cell.fill = Al_6061
clad_cell.region = clad_region

top_plug_1_cell = openmc.Cell(name="Top end plug upper peace")
top_plug_1_cell.fill = Al_1100
top_plug_1_cell.region = top_plug_1_region
top_plug_2_cell = openmc.Cell(name="Top end plug lower peace")
top_plug_2_cell.fill = Al_1100
top_plug_2_cell.region = top_plug_2_region

lower_plug_cell = openmc.Cell(name="lower end plug")
lower_plug_cell.fill = Al_5052
lower_plug_cell.region = lower_plug_region

water_cell = openmc.Cell(name="water among rods")
water_cell.fill = water
water_cell.region = water_region

acrylic_cell = openmc.Cell(name="acrylic plate at the end")
acrylic_cell.fill = acrylic
acrylic_cell.region = acrylic_region
    
fuel_rod_universe = openmc.Universe(cells=[fuel_cell, clad_cell, top_plug_1_cell,
                                           top_plug_2_cell, lower_plug_cell, water_cell, acrylic_cell])

# %%
#Lattice Geometry
    #20x16, 22x16

n_rows = 20
n_cols = 16

n_rows2 = 22
n_cols2 = 16

assembly_gap = 10.05

assembly = openmc.RectLattice(name='20x16 Assembly')
assembly.pitch = (assembly_pitch, assembly_pitch)
assembly.lower_left = [-assembly_pitch * n_rows / 2, -assembly_pitch * n_cols / 2]
assembly.universes = [[fuel_rod_universe for _ in range(n_rows)] for _ in range(n_cols)]

assembly2 = openmc.RectLattice(name='22x16 Assembly')
assembly2.pitch = (assembly_pitch, assembly_pitch)
assembly2.lower_left = [-assembly_pitch * n_rows2 / 2, -assembly_pitch * n_cols2 / 2]
assembly2.universes = [[fuel_rod_universe for _ in range(n_rows2)] for _ in range(n_cols2)]

assembly_top = openmc.ZPlane(z0=+98.27)
assembly_bottom = openmc.ZPlane(z0=-2.54)

assembly_x_axis = assembly_pitch * n_rows
assembly_y_axis = assembly_pitch * n_cols

assembly2_x_axis = assembly_pitch * n_rows2
assembly2_y_axis = assembly_pitch * n_cols2

assembly_x_min = openmc.XPlane(x0=-assembly_x_axis/2)
assembly_x_max = openmc.XPlane(x0=+assembly_x_axis/2)
assembly_y_min = openmc.YPlane(y0=-assembly_y_axis/2)
assembly_y_max = openmc.YPlane(y0=+assembly_y_axis/2)

assembly2_x_min = openmc.XPlane(x0=-assembly2_x_axis/2)
assembly2_x_max = openmc.XPlane(x0=+assembly2_x_axis/2)
assembly2_y_min = openmc.YPlane(y0=-assembly2_y_axis/2)
assembly2_y_max = openmc.YPlane(y0=+assembly2_y_axis/2)

assembly_region = +assembly_x_min & -assembly_x_max & +assembly_y_min & -assembly_y_max & +assembly_bottom & -assembly_top
assembly_cell = openmc.Cell(name='20x16 Assembly Cell', fill=assembly, region=assembly_region)

assembly2_region = +assembly2_x_min & -assembly2_x_max & +assembly2_y_min & -assembly2_y_max & +assembly_bottom & -assembly_top
assembly2_cell = openmc.Cell(name='22x16 Assembly Cell', fill=assembly2, region=assembly2_region)

assembly_water_cell_parameters_x = (assembly_pitch*n_rows) + assembly_gap
assembly_water_cell_parameters_y = assembly_pitch*n_cols

assembly2_water_cell_parameters_x = (assembly_pitch*n_rows2) + assembly_gap
assembly2_water_cell_parameters_y = assembly_pitch*n_cols2

assembly_water_cell_x_min = openmc.XPlane(x0=-assembly_water_cell_parameters_x/2)
assembly_water_cell_x_max = openmc.XPlane(x0=+assembly_water_cell_parameters_x/2)
assembly_water_cell_y_min = openmc.YPlane(y0=-assembly_water_cell_parameters_y/2)
assembly_water_cell_y_max = openmc.YPlane(y0=+assembly_water_cell_parameters_y/2)

assembly2_water_cell_x_min = openmc.XPlane(x0=-assembly2_water_cell_parameters_x/2)
assembly2_water_cell_x_max = openmc.XPlane(x0=+assembly2_water_cell_parameters_x/2)
assembly2_water_cell_y_min = openmc.YPlane(y0=-assembly2_water_cell_parameters_y/2)
assembly2_water_cell_y_max = openmc.YPlane(y0=+assembly2_water_cell_parameters_y/2)

assembly_water_cell_top = openmc.ZPlane(z0=+98.27)
assembly_water_cell_bottom = openmc.ZPlane(z0=-2.54)

assembly_water_box_region = +assembly_water_cell_x_min & -assembly_water_cell_x_max & +assembly_water_cell_y_min & -assembly_water_cell_y_max & -assembly_water_cell_top & +assembly_water_cell_bottom
assembly2_water_box_region = +assembly2_water_cell_x_min & -assembly2_water_cell_x_max & +assembly2_water_cell_y_min & -assembly2_water_cell_y_max & -assembly_water_cell_top & +assembly_water_cell_bottom

assembly_water_region = assembly_water_box_region & ~assembly_region
assembly2_water_region = assembly2_water_box_region & ~assembly2_region

assembly_water_cell = openmc.Cell(name="water among assemblies")
assembly_water_cell.fill = water
assembly_water_cell.region = assembly_water_region

assembly2_water_cell = openmc.Cell(name="water among assemblies")
assembly2_water_cell.fill = water
assembly2_water_cell.region = assembly2_water_region

assembly_universe = openmc.Universe(name='20x16 Assembly Universe', cells=[assembly_cell, assembly_water_cell])
assembly2_universe = openmc.Universe(name='22x16 Assembly Universe', cells=[assembly2_cell, assembly2_water_cell])

# %%
n_rows3 = 3
n_cols3 = 1

Case4 = openmc.RectLattice(name='3x1 Case 4')
Case4.pitch = ((assembly_pitch*n_rows) + assembly_gap, assembly_pitch*n_cols)

Case4.lower_left = [-((assembly_pitch*n_rows + assembly_gap) * n_rows3) / 2, -assembly_pitch*n_cols / 2]

Case4.universes = [
    [assembly2_universe, assembly_universe, assembly2_universe]
]

Case4_top = openmc.ZPlane(z0=+98.27)
Case4_bottom = openmc.ZPlane(z0=-2.54)

Case4_x_axis = (22 * assembly_pitch) + assembly_gap + (20 * assembly_pitch) + assembly_gap + (22 * assembly_pitch)
Case4_y_axis = 16 * assembly_pitch

Case4_top = openmc.ZPlane(z0=+98.27)
Case4_bottom = openmc.ZPlane(z0=-2.54)
Case4_x_min = openmc.XPlane(x0=-Case4_x_axis/2)
Case4_x_max = openmc.XPlane(x0=+Case4_x_axis/2)
Case4_y_min = openmc.YPlane(y0=-Case4_y_axis/2)
Case4_y_max = openmc.YPlane(y0=+Case4_y_axis/2)

Case4_region = +Case4_x_min & -Case4_x_max & +Case4_y_min & -Case4_y_max & +Case4_bottom & -Case4_top

Case4_cell = openmc.Cell(name='3x1 Case 4 cell', fill=Case4, region=Case4_region)

# %%
#Outer Water Definitions

outerwater_x_axis = Case4_x_axis + 2 * 70        #70cm thick water reflector each side
outerwater_y_axis = Case4_y_axis + 2 * 70

outerwater_bottom = openmc.ZPlane(z0=-(15.3+2.54), boundary_type='vacuum') #15.3cm bottom water reflector
outerwater_top = openmc.ZPlane(z0=+98.27+15, boundary_type='vacuum')      #9.92cm top water reflector

outerwater_x_min = openmc.XPlane(x0=-outerwater_x_axis/2, boundary_type='vacuum')
outerwater_x_max = openmc.XPlane(x0=+outerwater_x_axis/2, boundary_type='vacuum')
outerwater_y_min = openmc.YPlane(y0=-outerwater_y_axis/2, boundary_type='vacuum')
outerwater_y_max = openmc.YPlane(y0=+outerwater_y_axis/2, boundary_type='vacuum')

outerwater_cell = openmc.Cell(name="Outer Water Reflector")
outerwater_cell.fill = water
outerwater_region = +outerwater_x_min & -outerwater_x_max & +outerwater_y_min & -outerwater_y_max & +outerwater_bottom & -outerwater_top & ~Case2_region 
outerwater_cell.region = outerwater_region

# Outer water universe
outer_water_cell = openmc.Cell(fill=water)
outer_universe = openmc.Universe(cells=[outer_water_cell])

assembly.outer = outer_universe
Case4.outer = outer_universe

root_universe = openmc.Universe(cells=[Case4_cell, outerwater_cell])

# %%
geometry = openmc.Geometry(root_universe)
geometry.export_to_xml()

# %%
root_universe.plot(origin=(0, 0, 50), basis='xy', width=(350, 200), pixels=[1200, 1200],
                   color_by='material', colors={water: 'blue'})
plt.title('Case 4 - XY View of Root Universe')
plt.savefig('case4_xy_view.pdf')
plt.show()

# %%
root_universe.plot(origin=(0, 5, 50), basis='xz', width=(350, 160), pixels=[5000, 3000],
                   color_by='material', colors={water: 'blue'})
plt.title('Case 4 - XZ View of Root Universe')
plt.savefig('case4_xz_view.pdf')
plt.show()

# %%
#Source definition
Case4_x_axis = (assembly_pitch * n_rows + assembly_gap) * n_rows2
Case4_y_axis = assembly_pitch * n_cols

source = openmc.IndependentSource()
source.space = openmc.stats.Box(
    lower_left=(-Case4_x_axis / 2, -Case4_y_axis / 2, 0.0),
    upper_right=(Case4_x_axis / 2, Case4_y_axis / 2, 90.0)
)
source.angle = openmc.stats.Isotropic()
source.energy = openmc.stats.Watt(a=0.988, b=2.249)  # Watt spektrum

#Simulation Settings
settings = openmc.Settings()
settings.run_mode = 'eigenvalue'
settings.source = source
settings.batches = 210            # total = inactive + active
settings.inactive = 50
settings.particles = 50000       # number of particle for each batch
settings.seed = 123456
settings.export_to_xml()

# Tallies
fuel_tally = openmc.Tally(name="fuel_flux")
fuel_tally.filters = [openmc.CellFilter(fuel_cell)]
fuel_tally.scores = ["flux", "fission", "nu-fission", "heating-local"]  # MCNP F4, F6, F8

tallies = openmc.Tallies([fuel_tally])
tallies.export_to_xml()

openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2024 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.0
#         Git SHA1 | 84fb85977f46e162fea8f5a20ea653a3ec62ac24
#        Date/Time | 2025-05-28 14:49:17
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U234 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading O17 from /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/O17.h5
#  Reading Al27 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Al27.h5
#  Reading Cr50 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Cu63 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Cu63.h5
#  Reading Cu65 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Cu65.h5
#  Reading Mg24 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Mg24.h5
#  Reading Mg25 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Mg25.h5
#  Reading Mg26 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Mg26.h5
#  Reading Ti46 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Ti46.h5
#  Reading Ti47 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Ti47.h5
#  Reading Ti48 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Ti48.h5
#  Reading Ti49 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Ti49.h5
#  Reading Ti50 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Ti50.h5
#  Reading Zn64 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Zn64.h5
#  Reading Zn66 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Zn66.h5
#  Reading Zn67 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Zn67.h5
#  Reading Zn68 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Zn68.h5
#  Reading Zn70 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Zn70.h5
#  Reading Si28 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading Fe54 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Mn55 from
#  /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading H1 from /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading H2 from /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/H2.h5
#  Reading C0 from /home/buyrukcueray/openmc_data/endfb-vii.1-hdf5/neutron/C0.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.65140
#         2/1    0.98736
#         3/1    1.00430
#         4/1    1.00488
#         5/1    1.00564
#         6/1    1.02366
#         7/1    1.01353
#         8/1    1.01200
#         9/1    1.01649
#        10/1    1.01627
#        11/1    1.01348
#        12/1    1.01830
#        13/1    1.02475
#        14/1    1.01646
#        15/1    1.01858
#        16/1    1.02326
#        17/1    1.01913
#        18/1    1.02667
#        19/1    1.01558
#        20/1    1.02099
#        21/1    1.03049
#        22/1    1.02020
#        23/1    1.01577
#        24/1    1.02741
#        25/1    1.01729
#        26/1    1.03093
#        27/1    1.02918
#        28/1    1.03091
#        29/1    1.01956
#        30/1    1.02305
#        31/1    1.01812
#        32/1    1.02564
#        33/1    1.01392
#        34/1    1.02113
#        35/1    1.02928
#        36/1    1.01070
#        37/1    1.01987
#        38/1    1.02812
#        39/1    1.01683
#        40/1    1.01878
#        41/1    1.02631
#        42/1    1.02221
#        43/1    1.01803
#        44/1    1.01829
#        45/1    1.02264
#        46/1    1.02815
#        47/1    1.02476
#        48/1    1.02262
#        49/1    1.01762
#        50/1    1.02189
#        51/1    1.01773
#        52/1    1.02365    1.02069 +/- 0.00296
#        53/1    1.01875    1.02005 +/- 0.00183
#        54/1    1.01515    1.01882 +/- 0.00178
#        55/1    1.01577    1.01821 +/- 0.00151
#        56/1    1.01564    1.01778 +/- 0.00130
#        57/1    1.02358    1.01861 +/- 0.00138
#        58/1    1.01337    1.01795 +/- 0.00136
#        59/1    1.01531    1.01766 +/- 0.00124
#        60/1    1.02538    1.01843 +/- 0.00135
#        61/1    1.02209    1.01876 +/- 0.00126
#        62/1    1.01338    1.01832 +/- 0.00124
#        63/1    1.01832    1.01832 +/- 0.00114
#        64/1    1.02099    1.01851 +/- 0.00107
#        65/1    1.01330    1.01816 +/- 0.00106
#        66/1    1.01322    1.01785 +/- 0.00104
#        67/1    1.02043    1.01800 +/- 0.00098
#        68/1    1.02501    1.01839 +/- 0.00101
#        69/1    1.02446    1.01871 +/- 0.00100
#        70/1    1.02013    1.01878 +/- 0.00096
#        71/1    1.01492    1.01860 +/- 0.00093
#        72/1    1.00928    1.01818 +/- 0.00098
#        73/1    1.02023    1.01826 +/- 0.00094
#        74/1    1.02946    1.01873 +/- 0.00101
#        75/1    1.01967    1.01877 +/- 0.00097
#        76/1    1.02463    1.01899 +/- 0.00096
#        77/1    1.01049    1.01868 +/- 0.00098
#        78/1    1.01529    1.01856 +/- 0.00095
#        79/1    1.01369    1.01839 +/- 0.00093
#        80/1    1.02870    1.01873 +/- 0.00096
#        81/1    1.02420    1.01891 +/- 0.00095
#        82/1    1.02254    1.01902 +/- 0.00093
#        83/1    1.01221    1.01882 +/- 0.00092
#        84/1    1.01199    1.01862 +/- 0.00092
#        85/1    1.00627    1.01826 +/- 0.00096
#        86/1    1.02106    1.01834 +/- 0.00093
#        87/1    1.01719    1.01831 +/- 0.00091
#        88/1    1.02188    1.01840 +/- 0.00089
#        89/1    1.01885    1.01842 +/- 0.00087
#        90/1    1.01458    1.01832 +/- 0.00085
#        91/1    1.01921    1.01834 +/- 0.00083
#        92/1    1.02415    1.01848 +/- 0.00082
#        93/1    1.02669    1.01867 +/- 0.00082
#        94/1    1.01526    1.01859 +/- 0.00081
#        95/1    1.02496    1.01873 +/- 0.00080
#        96/1    1.01741    1.01871 +/- 0.00079
#        97/1    1.01572    1.01864 +/- 0.00077
#        98/1    1.01978    1.01867 +/- 0.00076
#        99/1    1.01472    1.01859 +/- 0.00074
#       100/1    1.02142    1.01864 +/- 0.00073
#       101/1    1.02812    1.01883 +/- 0.00074
#       102/1    1.01853    1.01882 +/- 0.00073
#       103/1    1.02586    1.01895 +/- 0.00072
#       104/1    1.02218    1.01901 +/- 0.00071
#       105/1    1.01692    1.01898 +/- 0.00070
#       106/1    1.02567    1.01910 +/- 0.00070
#       107/1    1.02491    1.01920 +/- 0.00069
#       108/1    1.01530    1.01913 +/- 0.00069
#       109/1    1.02669    1.01926 +/- 0.00069
#       110/1    1.01785    1.01924 +/- 0.00067
#       111/1    1.01482    1.01916 +/- 0.00067
#       112/1    1.02507    1.01926 +/- 0.00066
#       113/1    1.02633    1.01937 +/- 0.00066
#       114/1    1.02272    1.01942 +/- 0.00065
#       115/1    1.02167    1.01946 +/- 0.00064
#       116/1    1.01974    1.01946 +/- 0.00064
#       117/1    1.03052    1.01963 +/- 0.00065
#       118/1    1.01568    1.01957 +/- 0.00064
#       119/1    1.01273    1.01947 +/- 0.00064
#       120/1    1.02680    1.01957 +/- 0.00064
#       121/1    1.02646    1.01967 +/- 0.00064
#       122/1    1.01213    1.01957 +/- 0.00064
#       123/1    1.01646    1.01952 +/- 0.00063
#       124/1    1.02169    1.01955 +/- 0.00062
#       125/1    1.02136    1.01958 +/- 0.00061
#       126/1    1.01428    1.01951 +/- 0.00061
#       127/1    1.02295    1.01955 +/- 0.00060
#       128/1    1.02072    1.01957 +/- 0.00059
#       129/1    1.02377    1.01962 +/- 0.00059
#       130/1    1.00499    1.01944 +/- 0.00061
#       131/1    1.01834    1.01942 +/- 0.00060
#       132/1    1.01619    1.01938 +/- 0.00060
#       133/1    1.02539    1.01946 +/- 0.00059
#       134/1    1.00924    1.01934 +/- 0.00060
#       135/1    1.02609    1.01941 +/- 0.00060
#       136/1    1.02386    1.01947 +/- 0.00059
#       137/1    1.02084    1.01948 +/- 0.00059
#       138/1    1.01954    1.01948 +/- 0.00058
#       139/1    1.02052    1.01949 +/- 0.00057
#       140/1    1.02306    1.01953 +/- 0.00057
#       141/1    1.01350    1.01947 +/- 0.00057
#       142/1    1.02840    1.01957 +/- 0.00057
#       143/1    1.02337    1.01961 +/- 0.00056
#       144/1    1.03864    1.01981 +/- 0.00059
#       145/1    1.02287    1.01984 +/- 0.00059
#       146/1    1.01691    1.01981 +/- 0.00058
#       147/1    1.00796    1.01969 +/- 0.00059
#       148/1    1.01687    1.01966 +/- 0.00058
#       149/1    1.02849    1.01975 +/- 0.00058
#       150/1    1.03064    1.01986 +/- 0.00059
#       151/1    1.02462    1.01990 +/- 0.00058
#       152/1    1.01858    1.01989 +/- 0.00058
#       153/1    1.02926    1.01998 +/- 0.00058
#       154/1    1.02754    1.02006 +/- 0.00058
#       155/1    1.01389    1.02000 +/- 0.00058
#       156/1    1.01944    1.01999 +/- 0.00057
#       157/1    1.01831    1.01998 +/- 0.00057
#       158/1    1.02874    1.02006 +/- 0.00057
#       159/1    1.02055    1.02006 +/- 0.00056
#       160/1    1.01491    1.02001 +/- 0.00056
#       161/1    1.01975    1.02001 +/- 0.00055
#       162/1    1.02533    1.02006 +/- 0.00055
#       163/1    1.01536    1.02002 +/- 0.00055
#       164/1    1.01397    1.01996 +/- 0.00055
#       165/1    1.01554    1.01993 +/- 0.00054
#       166/1    1.01970    1.01992 +/- 0.00054
#       167/1    1.02774    1.01999 +/- 0.00054
#       168/1    1.01532    1.01995 +/- 0.00053
#       169/1    1.01889    1.01994 +/- 0.00053
#       170/1    1.02197    1.01996 +/- 0.00053
#       171/1    1.02270    1.01998 +/- 0.00052
#       172/1    1.01160    1.01991 +/- 0.00052
#       173/1    1.01556    1.01988 +/- 0.00052
#       174/1    1.01149    1.01981 +/- 0.00052
#       175/1    1.02696    1.01987 +/- 0.00052
#       176/1    1.01021    1.01979 +/- 0.00052
#       177/1    1.01715    1.01977 +/- 0.00052
#       178/1    1.01952    1.01977 +/- 0.00051
#       179/1    1.02865    1.01984 +/- 0.00051
#       180/1    1.02150    1.01985 +/- 0.00051
#       181/1    1.01298    1.01980 +/- 0.00051
#       182/1    1.02540    1.01984 +/- 0.00051
#       183/1    1.02940    1.01991 +/- 0.00051
#       184/1    1.01583    1.01988 +/- 0.00050
#       185/1    1.01914    1.01988 +/- 0.00050
#       186/1    1.01299    1.01983 +/- 0.00050
#       187/1    1.01465    1.01979 +/- 0.00050
#       188/1    1.01977    1.01979 +/- 0.00049
#       189/1    1.01900    1.01978 +/- 0.00049
#       190/1    1.02028    1.01979 +/- 0.00049
#       191/1    1.00901    1.01971 +/- 0.00049
#       192/1    1.01695    1.01969 +/- 0.00049
#       193/1    1.02328    1.01971 +/- 0.00048
#       194/1    1.02425    1.01975 +/- 0.00048
#       195/1    1.01797    1.01973 +/- 0.00048
#       196/1    1.01542    1.01970 +/- 0.00047
#       197/1    1.02461    1.01974 +/- 0.00047
#       198/1    1.02473    1.01977 +/- 0.00047
#       199/1    1.01875    1.01976 +/- 0.00047
#       200/1    1.02031    1.01977 +/- 0.00046
#       201/1    1.02030    1.01977 +/- 0.00046
#       202/1    1.01896    1.01977 +/- 0.00046
#       203/1    1.02037    1.01977 +/- 0.00046
#       204/1    1.00694    1.01969 +/- 0.00046
#       205/1    1.01574    1.01966 +/- 0.00046
#       206/1    1.02179    1.01967 +/- 0.00046
#       207/1    1.01213    1.01963 +/- 0.00045
#       208/1    1.01567    1.01960 +/- 0.00045
#       209/1    1.02400    1.01963 +/- 0.00045
#       210/1    1.01445    1.01960 +/- 0.00045
#  Creating state point statepoint.210.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.0747e+00 seconds
#    Reading cross sections          = 4.0333e+00 seconds
#  Total time in simulation          = 8.0095e+02 seconds
#    Time in transport only          = 7.9849e+02 seconds
#    Time in inactive batches        = 1.6944e+02 seconds
#    Time in active batches          = 6.3151e+02 seconds
#    Time synchronizing fission bank = 1.5821e+00 seconds
#      Sampling source sites         = 1.3337e+00 seconds
#      SEND/RECV source sites        = 2.4504e-01 seconds
#    Time accumulating tallies       = 1.8659e-01 seconds
#    Time writing statepoints        = 8.4194e-02 seconds
#  Total time for finalization       = 4.0560e-04 seconds
#  Total time elapsed                = 8.0507e+02 seconds
#  Calculation Rate (inactive)       = 14754.7 particles/second
#  Calculation Rate (active)         = 12668 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.01956 +/- 0.00041
#  k-effective (Track-length)  = 1.01960 +/- 0.00045
#  k-effective (Absorption)    = 1.02009 +/- 0.00038
#  Combined k-effective        = 1.01988 +/- 0.00033
#  Leakage Fraction            = 0.00265 +/- 0.00002
